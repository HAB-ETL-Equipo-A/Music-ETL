# %%
from classifier import Classifier
import json
import pandas as pd

# %%
cls = Classifier('zero-shot-classification', 'roberta-large-mnli')
# Out:
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
with open('datasets/rank_1/lyrics.json', 'r') as file:
    lyrics_json = json.load(file)
lyrics = [lyrics_json[i]['lyrics'] for i in lyrics_json]
track_ids = [lyrics_json[i]['track_id'] for i in lyrics_json]

# %%
with open('datasets/topic_labels.json', 'r') as file:
    labels_json = json.load(file)
label_pairs = labels_json['labels']
label_pairs
# Out:
# [['OPTIMISM', 'PESSIMISM'],
#  ['LOVE', 'HATE'],
#  ['HOPE', 'DESPAIR'],
#  ['STRENGTH', 'WEAKNESS'],
#  ['SUCCESS', 'FAILURE'],
#  ['FORGIVENESS', 'RESENTMENT'],
#  ['PEACE', 'CHAOS']]

# %%
# %%time
results = cls.classify(lyrics, label_pairs)
# Out:
# CPU times: user 12 s, sys: 491 ms, total: 12.5 s
# Wall time: 8.45 s

# %%
df = pd.DataFrame(results, index=track_ids)
df.index.name = 'track_id'

# %%
df
# Out:
#                         OPTIMISM  PESSIMISM      LOVE      HATE      HOPE  \
# track_id
# 5ayybTSXNwcarDtxQKqvWX  0.509144   0.490856  0.801051  0.198949  0.714910
# 006Ndmw2hHxvnLbJsBFnPx  0.539714   0.460286  0.590999  0.409001  0.625337
# 6xupOaBWORbDmakCdQwMRG  0.582897   0.417102  0.954446  0.045554  0.679851
# 2tvt5K7y1gndmCgtIoLo1f  0.702907   0.297093  0.912151  0.087849  0.816118
# 1xVOttVNT27FBTD8iHjOfU  0.741109   0.258890  0.919729  0.080271  0.873529
# 2qLxtO0iaFGI9x19vU3bDI  0.588334   0.411666  0.597810  0.402190  0.771861
# 5msxn2HUcd83qOsuQW7Kdb  0.682130   0.317870  0.985261  0.014739  0.793153
# 02NKMA9cIkq6VuBNu9q9Wf  0.651463   0.348537  0.691066  0.308934  0.719240
# 2vSxjnyrWrtxyfzO47EX6q  0.602642   0.397358  0.956853  0.043147  0.752910
# 7qoaMWT3eRCKG1RN6dVuOY  0.576990   0.423010  0.572300  0.427700  0.518996
# 5kqXQHIgQ6UfFP9LfqPNgG  0.530340   0.469660  0.980116  0.019884  0.787951
# 603N4XGJUTbK760GLCvIIs  0.581322   0.418677  0.736935  0.263065  0.600477
# 6fOxrKUo3f9OX2z6YrBpwy  0.000000   0.000000  0.000000  0.000000  0.000000
# 4GvyP7CnBJEV2t7L7vOkjw  0.538434   0.461566  0.508640  0.491360  0.687971
# 66eFGhs8LXeBgrXk0YgRJK  0.535474   0.464526  0.536706  0.463294  0.541608
# 44deyFcIU1jArZyFhOznh9  0.508170   0.491830  0.970317  0.029683  0.749150
# 3GI4aSJU8HrTM6msYXz1MT  0.665757   0.334243  0.961754  0.038246  0.521988
# 5xghdTMuqQPqtDJ0bn3zkn  0.538221   0.461779  0.934068  0.065932  0.589743
# 0yK8sWD6cfrc7pGfaPIcZH  0.506315   0.493685  0.803561  0.196439  0.830273
# 3E5ndyOfO6vFDEIE42HA8o  0.522347   0.477653  0.748191  0.251809  0.882127
#
#                          DESPAIR  STRENGTH  WEAKNESS   SUCCESS   FAILURE  \
# track_id
# 5ayybTSXNwcarDtxQKqvWX  0.285090  0.643750  0.356250  0.717940  0.282060
# 006Ndmw2hHxvnLbJsBFnPx  0.374663  0.546861  0.453139  0.578891  0.421109
# 6xupOaBWORbDmakCdQwMRG  0.320149  0.665997  0.334003  0.700274  0.299726
