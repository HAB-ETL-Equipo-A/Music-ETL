# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from etl_plots import ETLPlots

# %%
plotter = ETLPlots('datasets/')
plots = plotter.all_plots()
# Out:
# /home/human/Documents/HAB/Music-ETL/etl_plots.py:30: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   features_df[float_cols].hist(ax=ax, bins=40, layout=(3, 5))
