# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from etl_plots import ETLPlots

# %%
plotter = ETLPlots()

# %%
plotter.all_plots()
# Out:
# /home/human/Desktop/Music-ETL/etl_plots.py:48: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   features_df[float_cols].hist(ax=ax, bins=40, layout=(3, 5))
# [<Figure size 1200x600 with 15 Axes>,
#  <Figure size 1200x800 with 1 Axes>,
#  <Figure size 800x600 with 1 Axes>,
#  <Figure size 1200x600 with 1 Axes>,
#  <Figure size 1400x300 with 1 Axes>,
#  <Figure size 1000x600 with 1 Axes>,
#  <Figure size 1000x600 with 1 Axes>]
